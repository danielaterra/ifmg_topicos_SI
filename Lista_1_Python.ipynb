# %% [markdown]
# <a href="https://colab.research.google.com/github/danielaterra/ifmg_topicos_SI/blob/main/Lista_1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Exercício 1 Python
#
#
#
# Bacharelado em Sistemas de Informação - IFMG/Ouro Branco
#
# **Profa. Daniela Costa Terra**

# %%
import sys
import time
import numpy as np  # importa o pacote com 'alias' ou apelido de 'np'
import math
import matplotlib.pyplot as plt    # o módulo pyplot, parte do matplotlib, como plt
np.random.seed(1000)    ## produz o mesmos numeros 'pseudo'aleatórios a cada execução

# %% [markdown]
# Resolva usando código Python, as questões a seguir:
#
# 1.  Plote a distribuição de frequencia das faces resultantes, em um gráfico de barras, para o lançamento de um dado 1.000.000 de vezes.
# 2.  Plote a distribuição de frequencia da soma das 2 faces resultantes, em um gráfico de barras, para o lançamento de um dado 1.000.000 de vezes.
# 3.  Permita que o usuário defina a quantidade de dados e o número de lançamentos para cada dado. Você deve exibir o mesmo tipo de gráfico.
# 4.  Implemente uma solução para o problema da mochila usando uma heurística construtiva, conforme os dados abaixo.
#
# ![image.png](data:image/png;base64,...) ![mochila.jpg]( )

# %% [markdown]
# 4.  Baixe o arquivo  https://github.com/danielaterra/ifmg_topicos_SI/blob/main/C50.TXT e use o código abaixo para ler do arquivo no formato:
# *  cidadeDe   cidadeAte   distância*
#
#
# ```
# def le_arq_vetor(arquivo):
#     v = []
#     with open(arquivo, "r") as arquivo:
#       linhas = arquivo.readlines()
#       #print(linhas)
#     for linha in linhas:
#         v.append(int(linha))
#     return np.array(v)
# ```
#
#
# 5.  Use os dados do problema TSP de 50 cidades (no arquivo C50.TXT) e gere uma solução inicial usando a heurística gulosa de caminho mais curto. O viajante deve partir da cidade 10.
# 6.  Use os dados do problema TSP de 50 cidades (no arquivo C50.TXT) e gere uma solução inicial usando a heurística gulosa de inserção do aresta de menor custo. O viajante deve partir da cidade 10.
# 7.  Dado 5 elementos de um conjunto {A, B, C, D, E}, gere todas as permutações possíveis.
# 8.  Dado 5 elementos de um conjunto {A, B, C, D, E}, gere cada uma das combinações possíveis.
